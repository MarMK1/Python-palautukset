# %%
import pandas as pd
import numpy as np
import csv

df = pd.read_csv("C:/Users/mariu/Downloads/ObesityDataSet_raw_and_data_sinthetic (1).csv")
type(df)


df.info()

#Puuttuu product ja sum
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Age                             2111 non-null   float64
#  1   Gender                          2111 non-null   object
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   CALC                            2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   SCC                             2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  family_history_with_overweight  2111 non-null   object
# ...

# %%
df.head(10)
# Out:
#     Age  Gender  Height  Weight        CALC FAVC  FCVC  NCP  SCC SMOKE  CH2O  \
# 0  21.0  Female    1.62    64.0          no   no   2.0  3.0   no    no   2.0
# 1  21.0  Female    1.52    56.0   Sometimes   no   3.0  3.0  yes   yes   3.0
# 2  23.0    Male    1.80    77.0  Frequently   no   2.0  3.0   no    no   2.0
# 3  27.0    Male    1.80    87.0  Frequently   no   3.0  3.0   no    no   2.0
# 4  22.0    Male    1.78    89.8   Sometimes   no   2.0  1.0   no    no   2.0
# 5  29.0    Male    1.62    53.0   Sometimes  yes   2.0  3.0   no    no   2.0
# 6  23.0  Female    1.50    55.0   Sometimes  yes   3.0  3.0   no    no   2.0
# 7  22.0    Male    1.64    53.0   Sometimes   no   2.0  3.0   no    no   2.0
# 8  24.0    Male    1.78    64.0  Frequently  yes   3.0  3.0   no    no   2.0
# 9  22.0    Male    1.72    68.0          no  yes   2.0  3.0   no    no   2.0
#
#   family_history_with_overweight  FAF  TUE       CAEC                 MTRANS  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Height', 'Weight', 'CALC', 'FAVC', 'FCVC', 'NCP',
#        'SCC', 'SMOKE', 'CH2O', 'family_history_with_overweight', 'FAF', 'TUE',
#        'CAEC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %%
df.shape
# Out:
# (2111, 17)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2111, step=1)

# %%
df.values
# Out:
# array([[21.0, 'Female', 1.62, ..., 'Sometimes', 'Public_Transportation',
#         'Normal_Weight'],
#        [21.0, 'Female', 1.52, ..., 'Sometimes', 'Public_Transportation',
#         'Normal_Weight'],
#        [23.0, 'Male', 1.8, ..., 'Sometimes', 'Public_Transportation',
#         'Normal_Weight'],
#        ...,
#        [22.524036, 'Female', 1.752206, ..., 'Sometimes',
#         'Public_Transportation', 'Obesity_Type_III'],
#        [24.361936, 'Female', 1.73945, ..., 'Sometimes',
#         'Public_Transportation', 'Obesity_Type_III'],
#        [23.664709, 'Female', 1.738836, ..., 'Sometimes',
#         'Public_Transportation', 'Obesity_Type_III']], dtype=object)

# %%
column_data_types = df.dtypes
print(column_data_types)
# Out:
# Age                               float64
# Gender                             object
# Height                            float64
# Weight                            float64
# CALC                               object
# FAVC                               object
# FCVC                              float64
# NCP                               float64
# SCC                                object
# SMOKE                              object
# CH2O                              float64
# family_history_with_overweight     object
# FAF                               float64
# TUE                               float64
# CAEC                               object
# MTRANS                             object
# NObeyesdad                         object
# dtype: object

# %%
column_data_type = df['Height'].dtype
print(column_data_type)
# Out:
# float64

# %%
df.sort_values("Age")
# Out:
#             Age  Gender    Height     Weight        CALC FAVC  FCVC  NCP SCC  \
# 415   14.000000    Male  1.710000  72.000000          no  yes   3.0  3.0  no
# 116   15.000000  Female  1.650000  86.000000          no  yes   3.0  3.0  no
# 309   16.000000  Female  1.660000  58.000000          no   no   2.0  1.0  no
# 295   16.000000  Female  1.660000  58.000000          no   no   2.0  1.0  no
# 303   16.000000  Female  1.570000  49.000000   Sometimes  yes   2.0  4.0  no
# ...         ...     ...       ...        ...         ...  ...   ...  ...  ..
# 1158  55.022494    Male  1.673394  80.400306          no  yes   2.0  3.0  no
# 1088  55.137881    Male  1.657221  80.993213          no  yes   2.0  3.0  no
# 1013  55.246250    Male  1.769269  80.491339          no  yes   2.0  3.0  no
# 252   56.000000    Male  1.790000  90.000000  Frequently   no   2.0  3.0  no
# 133   61.000000  Female  1.650000  66.000000  Frequently  yes   3.0  3.0  no
#
# ...

# %%
df.sort_values("Age", ascending=False)
# Out:
#             Age  Gender    Height     Weight        CALC FAVC  FCVC  NCP SCC  \
# 133   61.000000  Female  1.650000  66.000000  Frequently  yes   3.0  3.0  no
# 252   56.000000    Male  1.790000  90.000000  Frequently   no   2.0  3.0  no
# 1013  55.246250    Male  1.769269  80.491339          no  yes   2.0  3.0  no
# 1088  55.137881    Male  1.657221  80.993213          no  yes   2.0  3.0  no
# 1158  55.022494    Male  1.673394  80.400306          no  yes   2.0  3.0  no
# ...         ...     ...       ...        ...         ...  ...   ...  ...  ..
# 312   16.000000  Female  1.600000  57.000000          no  yes   3.0  3.0  no
# 295   16.000000  Female  1.660000  58.000000          no   no   2.0  1.0  no
# 290   16.000000    Male  1.820000  71.000000   Sometimes  yes   2.0  3.0  no
# 116   15.000000  Female  1.650000  86.000000          no  yes   3.0  3.0  no
# 415   14.000000    Male  1.710000  72.000000          no  yes   3.0  3.0  no
#
# ...

# %%
df.sort_values(["Age", "Height"])
df.sort_values(["Weight", "TUE"], ascending=[True, False])
# Out:
#             Age  Gender    Height      Weight       CALC FAVC      FCVC  \
# 395   20.000000  Female  1.540000   39.000000  Sometimes  yes  1.000000
# 725   19.994543  Female  1.537739   39.101805  Sometimes  yes  1.118436
# 589   19.948140  Female  1.530884   39.371523  Sometimes  yes  1.522001
# 636   19.054008  Female  1.556611   39.695295  Sometimes  yes  1.889199
# 588   18.530840  Female  1.573816   39.850137  Sometimes  yes  1.214980
# ...         ...     ...       ...         ...        ...  ...       ...
# 1838  20.989016  Female  1.807340  155.872093  Sometimes  yes  3.000000
# 1910  21.521294  Female  1.803677  160.639405  Sometimes  yes  3.000000
# 1898  19.472190  Female  1.793824  160.935351  Sometimes  yes  3.000000
# 502   21.900120  Female  1.843419  165.057269  Sometimes  yes  3.000000
# 344   18.000000    Male  1.870000  173.000000  Sometimes  yes  3.000000
#
#            NCP SCC SMOKE      CH2O family_history_with_overweight       FAF  \
# ...

# %%
subset_df = df["Age"]
print(subset_df)

subset_df1 = df[["Height", "Weight"]]
print(subset_df1)
# Out:
# 0       21.000000
# 1       21.000000
# 2       23.000000
# 3       27.000000
# 4       22.000000
#           ...
# 2106    20.976842
# 2107    21.982942
# 2108    22.524036
# 2109    24.361936
# 2110    23.664709
# Name: Age, Length: 2111, dtype: float64
#         Height      Weight
# 0     1.620000   64.000000
# 1     1.520000   56.000000
# 2     1.800000   77.000000
# 3     1.800000   87.000000
# 4     1.780000   89.800000
# ...        ...         ...
# 2106  1.710730  131.408528
# 2107  1.748584  133.742943
# 2108  1.752206  133.689352
# 2109  1.739450  133.346641
# 2110  1.738836  133.472641
#
# [2111 rows x 2 columns]

# %%
subset_df = df[df['Age'] > 30]
print(subset_df)

subset_df = df[df['Age'] == "50"]
print(subset_df)


subset_df1 = df['Age'] > 30
subset_df2 = df['Age'] == "50"
subset_df3 = df[subset_df1 & subset_df2]
subset_df3.head()
# Out:
#             Age  Gender    Height      Weight        CALC FAVC      FCVC  \
# 13    41.000000    Male  1.800000   99.000000  Frequently  yes  2.000000
# 21    52.000000  Female  1.690000   87.000000          no  yes  3.000000
# 31    31.000000  Female  1.580000   68.000000   Sometimes   no  2.000000
# 33    39.000000    Male  1.790000   90.000000   Sometimes   no  2.000000
# 92    55.000000    Male  1.780000   84.000000  Frequently   no  3.000000
# ...         ...     ...       ...         ...         ...  ...       ...
# 1778  38.112989    Male  1.766888  118.134898   Sometimes  yes  2.240757
# 1781  33.722449    Male  1.712905  103.276087          no  yes  2.525884
# 1782  32.516469    Male  1.695735  102.784864          no  yes  2.736647
# 1793  30.715160    Male  1.650189  101.141277          no  yes  2.913452
# 1794  30.642430    Male  1.653876  102.583895          no  yes  2.919526
#
#            NCP  SCC SMOKE      CH2O family_history_with_overweight       FAF  \
# ...
